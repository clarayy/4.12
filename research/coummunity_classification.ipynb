# %%
import numpy as np
import random
import networkx as nx
from IPython.display import Image
import matplotlib.pyplot as plt

# %%
from networkx.algorithms import community
from itertools import islice
k =2
N = 1000
#B = np.load("/home/zhang/Documents/research/graph_python/BA200.npy")#读取固定的图
B = np.load("/home/iot/zcy/usb/copy/research/graph_python/BA1000.npy")#读取固定的图

G = nx.Graph(B)
print(len(G.edges()))
comp = community.girvan_newman(G)
for communities in islice(comp, k):
    a = tuple(sorted(c) for c in communities)
print(a)
dict_par = {}
for i in range(len(a)):#i=0~9
    for value in a[i]:
        # if i not in dict_par:
        #     dict_par[i] = []
        # dict_par[i].append(value)
        dict_par[value] = i
    i = i+1
print(dict_par)
# Out:
# 1191
# ...

# %%
# draw the graph
pos = nx.spring_layout(G)
# color the nodes according to their partition
cmap = cm.get_cmap('viridis', max(dict_par.values()) + 1)
nx.draw_networkx_nodes(G, pos, dict_par.keys(), node_size=40,
                       cmap=cmap, node_color=list(dict_par.values()))
nx.draw_networkx_edges(G, pos, alpha=0.5)
nx.draw_networkx_labels(G,pos,font_size=5)
plt.show()

# %%
import community as community_louvain
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import networkx as nx

# load the karate club graph
#G = nx.karate_club_graph()
N = 2068
B = np.load("/home/iot/zcy/usb/copy/research/graph_python/p2p2068.npy")#读取固定的图
G = nx.Graph(B)
#first compute the best partition
partition = community_louvain.best_partition(G)
list1 = sorted(partition.items(), key=lambda partition:partition[1])
print(partition)
print(list1)

#print(list1)
# Out:
# {0: 0, 1: 0, 2: 1, 3: 4, 4: 3, 5: 2, 6: 4, 7: 1, 8: 5, 9: 2, 10: 7, 11: 5, 12: 7, 13: 5, 14: 4, 15: 0, 16: 1, 17: 0, 18: 5, 19: 5, 20: 5, 21: 1, 22: 1, 23: 7, 24: 7, 25: 1, 26: 7, 27: 7, 28: 5, 29: 2, 30: 3, 31: 2, 32: 5, 33: 2, 34: 1, 35: 0, 36: 7, 37: 5, 38: 0, 39: 0, 40: 0, 41: 7, 42: 8, 43: 0, 44: 7, 45: 2, 46: 7, 47: 0, 48: 2, 49: 7, 50: 5, 51: 3, 52: 0, 53: 1, 54: 4, 55: 1, 56: 2, 57: 7, 58: 2, 59: 7, 60: 8, 61: 8, 62: 0, 63: 7, 64: 2, 65: 5, 66: 0, 67: 0, 68: 5, 69: 5, 70: 0, 71: 5, 72: 7, 73: 2, 74: 2, 75: 3, 76: 7, 77: 0, 78: 4, 79: 2, 80: 5, 81: 7, 82: 7, 83: 0, 84: 5, 85: 0, 86: 0, 87: 7, 88: 3, 89: 0, 90: 1, 91: 3, 92: 8, 93: 0, 94: 3, 95: 3, 96: 4, 97: 5, 98: 0, 99: 0, 100: 0, 101: 7, 102: 0, 103: 1, 104: 0, 105: 7, 106: 8, 107: 3, 108: 0, 109: 0, 110: 3, 111: 0, 112: 8, 113: 0, 114: 1, 115: 5, 116: 0, 117: 7, 118: 0, 119: 2, 120: 7, 121: 7, 122: 3, 123: 7, 124: 0, 125: 0, 126: 0, 127: 7, 128: 1, 129: 7, 130: 2, 131: 7, 132: 3, 133: 1, 134: 7, 135: 2, 136: 5, 137: 2, 138
# ...

# %%
# draw the graph
pos = nx.spring_layout(G)
# color the nodes according to their partition
cmap = cm.get_cmap('viridis', max(partition.values()) + 1)
nx.draw_networkx_nodes(G, pos, partition.keys(), node_size=40,
                       cmap=cmap, node_color=list(partition.values()))
nx.draw_networkx_edges(G, pos, alpha=0.5)
nx.draw_networkx_labels(G,pos,font_size=5)
plt.show()

# %%
pcc_longueurs=list(nx.all_pairs_shortest_path_length(G))
n=20
distances=np.zeros((n,n))# distances[i, j] is the length of the shortest path between i and j
for i in range(n):
    for j in range(n):
        distances[i, j] = pcc_longueurs[i][1][j]

# %%
from sklearn.cluster import AgglomerativeClustering
clustering = AgglomerativeClustering(n_clusters=5,linkage='average',affinity='precomputed').fit_predict(distances)
nx.draw(G,  node_color = clustering)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/GNN/lib/python3.7/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4349             try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4350                 colors = mcolors.to_rgba_array(c)
#    4351             except (TypeError, ValueError) as err:
#
# ~/anaconda3/envs/GNN/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     384     else:
# --> 385         rgba = np.array([to_rgba(cc) for cc in c])
#     386
#
# ~/anaconda3/envs/GNN/lib/python3.7/site-packages/matplotlib/colors.py in <listcomp>(.0)
#     384     else:
# --> 385         rgba = np.array([to_rgba(cc) for cc in c])
#     386
#
# ~/anaconda3/envs/GNN/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
# ...

# %%
import community as community_louvain
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import networkx as nx

# load the karate club graph
# = nx.karate_club_graph()
G=nx.random_graphs.barabasi_albert_graph(200,3)
#first compute the best partition
partition = community_louvain.best_partition(G)
print(partition)
# compute the best partition
#partition = community_louvain.best_partition(G)
start_node=0
print(partition[start_node])
# draw the graph
pos = nx.spring_layout(G)
# color the nodes according to their partition
cmap = cm.get_cmap('viridis', max(partition.values()) + 1)
nx.draw_networkx_nodes(G, pos, partition.keys(), node_size=40,
                       cmap=cmap, node_color=list(partition.values()))
nx.draw_networkx_edges(G, pos, alpha=0.5)
plt.show()
# Out:
# {0: 0, 1: 1, 2: 2, 3: 7, 4: 4, 5: 5, 6: 6, 7: 7, 8: 8, 9: 8, 10: 7, 11: 0, 12: 8, 13: 4, 14: 5, 15: 3, 16: 5, 17: 2, 18: 1, 19: 2, 20: 2, 21: 0, 22: 4, 23: 0, 24: 4, 25: 2, 26: 5, 27: 5, 28: 0, 29: 3, 30: 6, 31: 7, 32: 2, 33: 4, 34: 5, 35: 4, 36: 2, 37: 5, 38: 6, 39: 0, 40: 1, 41: 2, 42: 2, 43: 5, 44: 7, 45: 2, 46: 1, 47: 5, 48: 6, 49: 8, 50: 0, 51: 1, 52: 2, 53: 7, 54: 8, 55: 5, 56: 2, 57: 8, 58: 3, 59: 8, 60: 1, 61: 5, 62: 5, 63: 8, 64: 1, 65: 3, 66: 8, 67: 7, 68: 8, 69: 6, 70: 7, 71: 7, 72: 2, 73: 1, 74: 4, 75: 0, 76: 2, 77: 3, 78: 4, 79: 1, 80: 7, 81: 3, 82: 8, 83: 2, 84: 0, 85: 7, 86: 0, 87: 4, 88: 0, 89: 0, 90: 0, 91: 2, 92: 5, 93: 3, 94: 2, 95: 0, 96: 6, 97: 4, 98: 5, 99: 5, 100: 2, 101: 3, 102: 8, 103: 8, 104: 6, 105: 7, 106: 5, 107: 5, 108: 6, 109: 1, 110: 3, 111: 4, 112: 1, 113: 1, 114: 2, 115: 0, 116: 7, 117: 0, 118: 0, 119: 1, 120: 1, 121: 8, 122: 3, 123: 2, 124: 5, 125: 7, 126: 0, 127: 4, 128: 4, 129: 0, 130: 5, 131: 8, 132: 7, 133: 1, 134: 4, 135: 5, 136: 2, 137: 0, 138
# ...

# %% [markdown]
# 1，2，3 和4，5和7是分开执行的。分别是grivan_newman和louvain社区分类方法，7是例程。
# 123中a表示每一类分别有那些节点，到时候取每一类中的第一个值作为源节点。
# 45中list1是将类按从小到大排列，相同类的节点连在一起，形成元组。.py在此基础上实现了

# %% [markdown]
# 与之前的所有程序无关
# 以下实验1000节点BA网络，n=3（n不能取小数怎么办），的分类情况：

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv
import networkx as nx
import os
import random
from itertools import islice 
import community as community_louvain
#生成scale_free网络，节点数400
#G = nx.scale_free_graph(40000)
#循环次数100，感染概率0.046
N =500#可以优化为不要每次都生成G，固定下来连接图
#G = nx.scale_free_graph(N)
#BA=nx.random_graphs.barabasi_albert_graph(N,1)
BA = np.load("/home/iot/zcy/usb/copy/research/graph_python/food500.npy")#读取固定的图
G=nx.Graph(BA)
#print('edges:',len(G.edges()))

partition = community_louvain.best_partition(G)
#np.save("dolphins_p.npy",partition)
#print(partition)
list1 = sorted(partition.items(), key=lambda partition:partition[1])
print(list1)
print(list1[len(list1)-1][1]+1)  #最后一个节点对应的类数，但+1才是总的分类数（从0开始）
list2 = []
list3 = []#相同的类作为一个列表放在一起
for i in range(list1[len(list1)-1][1]+1):
    for k,v in partition.items():
        if v==i:
            list2.append(k)
    list3.append(list2)
    list2 = []
print(list3)
# for i in range(len(list3)):
#     if len(list3[i]) >3:
#         print(list3[i][0])   #小于3个节点的小图类不算做一个社区，不计为源节点
for i in range(len(list3)):
    print(list3[i][0])
# Out:
# [(0, 0), (1, 0), (3, 0), (5, 0), (6, 0), (202, 0), (203, 0), (229, 0), (230, 0), (231, 0), (326, 0), (327, 0), (328, 0), (329, 0), (330, 0), (345, 0), (346, 0), (347, 0), (348, 0), (368, 0), (399, 0), (400, 0), (402, 0), (403, 0), (404, 0), (415, 0), (450, 0), (451, 0), (471, 0), (2, 1), (4, 1), (9, 1), (11, 1), (24, 1), (26, 1), (27, 1), (28, 1), (43, 1), (52, 1), (54, 1), (55, 1), (59, 1), (60, 1), (61, 1), (65, 1), (66, 1), (81, 1), (84, 1), (92, 1), (93, 1), (94, 1), (95, 1), (96, 1), (98, 1), (105, 1), (107, 1), (144, 1), (165, 1), (172, 1), (174, 1), (180, 1), (181, 1), (182, 1), (183, 1), (184, 1), (185, 1), (186, 1), (188, 1), (232, 1), (233, 1), (234, 1), (236, 1), (237, 1), (239, 1), (240, 1), (241, 1), (242, 1), (243, 1), (244, 1), (245, 1), (246, 1), (249, 1), (257, 1), (262, 1), (263, 1), (274, 1), (289, 1), (290, 1), (291, 1), (295, 1), (298, 1), (335, 1), (353, 1), (361, 1), (363, 1), (374, 1), (382, 1), (390, 1), (393, 1), (411, 1), (413, 1), (426, 1), (428, 1), (429,
# ...

# %%
import matplotlib.cm as cm
# draw the graph
pos = nx.spring_layout(G)
# color the nodes according to their partition
cmap = cm.get_cmap('viridis', max(partition.values()) + 1)
nx.draw_networkx_nodes(G, pos, partition.keys(), node_size=40,
                       cmap=cmap, node_color=list(partition.values()))
nx.draw_networkx_edges(G, pos, alpha=0.5)
nx.draw_networkx_labels(G,pos,font_size=8)
plt.show()
plt.show()

# %%
import numpy as np
import random
#from IPython.display import Image
import community as community_louvain
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import networkx as nx

# load the karate club graph
#G = nx.karate_club_graph()
N = 500
#B = np.load("/home/zhang/Documents/research/graph_python/BA500.npy")#读取固定的图
partition= np.load("/home/iot/zcy/usb/copy/research/graph_python/food500_p.npy",allow_pickle=True).item()#读取固定的图
print(partition)
list1 = sorted(partition.items(), key=lambda partition:partition[1])
#print(list1)
print(list1[len(list1)-1][1]+1)  #最后一个节点对应的类数，但+1才是总的分类数（从0开始）
list2 = []
list3 = []#相同的类作为一个列表放在一起
for i in range(list1[len(list1)-1][1]+1):
    for k,v in partition.items():
        if v==i:
            list2.append(k)
    list3.append(list2)
    list2 = []
print(list3)
#每类取5个节点，看准确率
node_10 = []
for i in range(len(list3)):
    c = list3[i][:10]
    node_10.extend(c)
print(node_10)
print(len(node_10))
# Out:
# {0: 0, 1: 0, 2: 1, 3: 0, 4: 1, 5: 0, 6: 0, 7: 2, 8: 2, 9: 1, 10: 3, 11: 3, 12: 3, 13: 4, 14: 4, 15: 4, 16: 4, 17: 5, 18: 4, 19: 4, 20: 4, 21: 4, 22: 4, 23: 2, 24: 3, 25: 3, 26: 3, 27: 3, 28: 3, 29: 2, 30: 2, 31: 1, 32: 2, 33: 10, 34: 10, 35: 10, 36: 10, 37: 10, 38: 8, 39: 9, 40: 1, 41: 9, 42: 9, 43: 3, 44: 9, 45: 9, 46: 10, 47: 1, 48: 10, 49: 10, 50: 10, 51: 1, 52: 1, 53: 1, 54: 3, 55: 3, 56: 1, 57: 1, 58: 1, 59: 3, 60: 1, 61: 1, 62: 3, 63: 1, 64: 1, 65: 3, 66: 3, 67: 1, 68: 1, 69: 1, 70: 1, 71: 1, 72: 1, 73: 1, 74: 6, 75: 10, 76: 10, 77: 5, 78: 10, 79: 5, 80: 1, 81: 3, 82: 1, 83: 3, 84: 3, 85: 4, 86: 2, 87: 2, 88: 2, 89: 2, 90: 2, 91: 1, 92: 1, 93: 1, 94: 1, 95: 1, 96: 3, 97: 1, 98: 1, 99: 6, 100: 6, 101: 6, 102: 6, 103: 6, 104: 1, 105: 3, 106: 2, 107: 3, 108: 1, 109: 1, 110: 5, 111: 5, 112: 8, 113: 8, 114: 2, 115: 2, 116: 8, 117: 2, 118: 8, 119: 8, 120: 8, 121: 8, 122: 8, 123: 2, 124: 8, 125: 2, 126: 8, 127: 8, 128: 2, 129: 8, 130: 8, 131: 8, 132: 8, 133: 2, 134: 1, 135: 8, 136: 8,
# ...
